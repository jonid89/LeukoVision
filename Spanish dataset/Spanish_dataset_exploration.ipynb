# %%
# Import libraries
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
folder_path = r"C:\Users\NtGNB\Downloads\Scientest\Project\Spanish dataset\PBC_dataset_normal_DIB"
base_path = Path(folder_path)

for group_folder in base_path.iterdir():
    if group_folder.is_dir():
        image_files = list(group_folder.glob("*.jpg")) + list(group_folder.glob("*.png"))


images = []
for image in image_files:
    images.append(plt.imread(image))

# %%
base_path.iterdir()
# Out:
# <generator object Path.iterdir at 0x000001A9C3F3BF20>
